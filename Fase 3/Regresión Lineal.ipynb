# %%
pip install numpy pandas scikit-learn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importanto bibliotecas
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("datos mas usables.csv")

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 261     city  2016           9.50          11.60       33988    Diesel
# 262     brio  2015           4.00           5.90       60000    Petrol
# 263     city  2009           3.35          11.00       87934    Petrol
# 264     city  2017          11.50          12.50        9000    Diesel
# 265     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
#Transformando a Dataframe
df = pd.DataFrame(data)

# %%
#escogiendo variable dependiente e independiente

x = df[["Selling_Price"]]
y = df["Present_Price"]

#creando modelo regresin lineal

modelo = LinearRegression()

#ajustar el modelo a los datos

modelo.fit(x, y)

#generando coeficientes
beta_0 = modelo.intercept_
beta_1 = modelo.coef_

#Mostrar los coeficientes

print(f"intercepto(): {beta_0}")
print(f"coeficiente(): {beta_1}")
# Out:
# intercepto(): 1.0276714009011254
# coeficiente(): [1.25328642]

# %%
plt.scatter(df["Selling_Price"], y, color = "blue", label = "datos reales")
plt.plot(df["Selling_Price"],  modelo.predict(x), color="red", label = "Linea de Regresion")
plt.title("Regresion Lineal: Kilometraje vs Precio de Venta")
plt.xlabel("Precio de Venta")
plt.ylabel("Precio actual")
plt.legend()
plt.show()

# %%
#predecir precios para nuevos Valores
nuevo_x = np.array([[55], [65]])
prediccion = modelo.predict(nuevo_x)

#Mostrar las predicciones
print("\nPredicciones: ")
for i, pred in enumerate(prediccion):
    print(f"predicción {i+1} para (Precio Actual: {nuevo_x[i][0]}$): {pred:.2f}$")
# Out:
# Predicciones:
# predicción 1 para (Precio Actual: 55$): 69.96$
# predicción 2 para (Precio Actual: 65$): 82.49$
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Variables independientes y dependientes
x = df [["Selling_Price", "Owner"]]
y = df ["Present_Price"]

#Crear un modelo de regresion lineal

modelo = LinearRegression()

modelo.fit(x, y)

#coeficientes regresion
beta_0 = modelo.intercept_
beta_1, beta_2 = modelo.coef_

#mostrar coeficientes

print(f"intercepto:(B0) {beta_0}")
print(f"coeficiente:(precio inicial) {beta_1}")
print(f"coeficiente:(propietarios) {beta_2}")


#visualizar la regresion

plt.scatter(df["Selling_Price"], y, color = "blue", label = "datos reales")
plt.plot(df["Selling_Price"],  modelo.predict(x), color="red", label = "Linea de Regresion")
plt.title("Regresion Lineal: Kilometraje vs Precio de Venta")
plt.xlabel("Precio de Venta")
plt.ylabel("Precio actual")
plt.legend()
plt.show()
# Out:
# intercepto:(B0) 1.0391948934472
# coeficiente:(precio inicial) 1.2520272493090763
# coeficiente:(kilometraje) -0.18968857458608013

# %%
#predecir precios para nuevos Valores
nuevo_x = np.array([[55, 2], [65, 1]])
prediccion = modelo.predict(nuevo_x)

#Mostrar las predicciones
print("\nPredicciones: ")
for i, pred in enumerate(prediccion):
    print(f"predicción {i+1} para (Precio Actual: {nuevo_x[i][0]}$), Propietarios: {nuevo_x[i][1]}): {pred:.2f}$")
# Out:
# Predicciones:
# predicción 1 para (Precio Actual: 55$), Propietarios: 2): 69.52$
# predicción 2 para (Precio Actual: 65$), Propietarios: 1): 82.23$
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#importar librerias para ver rango de error
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

#datos
x = df [["Selling_Price", "Owner"]]
y = df ["Present_Price"]

#Crear un modelo de regresion lineal

modelo = LinearRegression()

modelo.fit(x, y)

#realizar predicio
prediccion = modelo.predict(x)

#metricas de evaluación
r2 = r2_score(y, prediccion)
mae =mean_absolute_error(y, prediccion)
mse= mean_squared_error(y,prediccion)
rnse = np.sqrt(mse)

#mostrar metricas
print(f"R 2(coeficiente de determincación): {r2}")
print(f"Error absoluto medio: {mae}")
# Out:
# R 2(coeficiente de determincación): 0.7917701542009881
# Error absoluto medio: 1.306841116046218
